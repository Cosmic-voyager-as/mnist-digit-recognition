# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
(X_train,y_train),(X_test,y_teat)=keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train.shape # image stored as 28 pixels for each 28 rows
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[2])

# %%
X_train=X_train/255;
X_test=X_test/255

# %%
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,938 (409.91 KB)
#  Trainable params: 104,938 (409.91 KB)
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=25,validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9970 - loss: 0.0090 - val_accuracy: 0.9700 - val_loss: 0.2027
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9973 - loss: 0.0079 - val_accuracy: 0.9747 - val_loss: 0.1665
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 0.9703 - val_loss: 0.2081
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9748 - val_loss: 0.1730
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9980 - loss: 0.0074 - val_accuracy: 0.9758 - val_loss: 0.1717
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9763 - val_loss: 0.1699
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9736 - val_loss: 0.1796
# Epoch 8/25
# ...

# %%
y_prob = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
y_pred = y_prob.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_teat,y_pred)
# Out:
# 0.9775

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
# !git clone https://github.com/cosmic-voyager-as/mnist-digit-recognition.git
# Out:
# Cloning into 'mnist-digit-recognition'...
# ...

# %%
# %cd mnist-digit-recognition
# Out:
# /content/mnist-digit-recognition

# %%
# !ls /content
# Out:
# mnist-digit-recognition  sample_data

# %%
# !cp /content/MNSIT_DATASET_PREDICTOR.ipynb .
# Out:
# cp: cannot stat '/content/MNSIT_DATASET_PREDICTOR.ipynb': No such file or directory

# %%
# %cd mnist-digit-recognition
# Out:
# [Errno 2] No such file or directory: 'mnist-digit-recognition'
# /content/mnist-digit-recognition

# %%
# !git clone https://github.com/cosmic-voyager-as/mnist-digit-recognition.git
# Out:
# Cloning into 'mnist-digit-recognition'...
# ...

# %%
# %cd mnist-digit-recognition
# Out:
# /content/mnist-digit-recognition/mnist-digit-recognition

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# mnist-digit-recognition  sample_data

# %%
# !pwd
# Out:
# /content

# %%
# %cd mnist-digit-recognition
# Out:
# /content/mnist-digit-recognition

# %%
# !pwd
# Out:
# /content/mnist-digit-recognition

# %%
# !ls
# Out:
# mnist-digit-recognition

# %%
# !cp /content/MNSIT_DATASET_PREDICTOR.ipynb .
# Out:
# cp: cannot stat '/content/MNSIT_DATASET_PREDICTOR.ipynb': No such file or directory

# %%
# !find /content -name "*.ipynb"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "*.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Copy of MNSIT_DATASET_PREDICTOR.ipynb
# /content/drive/MyDrive/Colab Notebooks/MNSIT_DATASET_PREDICTOR.ipynb

# %%
# %cd /content/mnist-digit-recognition
# Out:
# /content/mnist-digit-recognition

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/MNSIT_DATASET_PREDICTOR.ipynb" .

# %%
# !ls
# Out:
# mnist-digit-recognition  MNSIT_DATASET_PREDICTOR.ipynb

# %%
# !git add .
# !git commit -m "Added MNIST ANN project"
# !git push origin main
# Out:
# error: 'mnist-digit-recognition/' does not have a commit checked out
# fatal: adding files failed
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@3716cd8d9f1b.(none)')
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/cosmic-voyager-as/mnist-digit-recognition.git'

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/mnist-digit-recognition/.git/

# %%
# !git config user.name "cosmic-voyager-as"
# !git config user.email "ashmika468@gmail.com"

# %%
# !ls
# Out:
# mnist-digit-recognition  MNSIT_DATASET_PREDICTOR.ipynb

# %%
# !git commit -m "Initial commit - MNIST ANN project"
# Out:
# On branch main
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	MNSIT_DATASET_PREDICTOR.ipynb
# 	mnist-digit-recognition/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %cd /content
# Out:
# /content

# %%
# !rm -rf mnist-digit-recognition

# %%
# !git clone https://github.com/cosmic-voyager-as/mnist-digit-recognition.git
# Out:
# Cloning into 'mnist-digit-recognition'...
# ...

# %%
# %cd mnist-digit-recognition
# Out:
# /content/mnist-digit-recognition

# %%
# !git config --global user.name "cosmic-voyager-as"
# !git config --global user.email "ashmika468@gmail.com"

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/MNSIT_DATASET_PREDICTOR.ipynb" .

# %%
# !git add .
# !git commit -m "Added MNIST ANN project"
# !git push -u origin main
# Out:
# [main (root-commit) d40e49d] Added MNIST ANN project
#  1 file changed, 1 insertion(+)
#  create mode 100644 MNSIT_DATASET_PREDICTOR.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin https://github.com/cosmic-voyager-as/mnist-digit-recognition.git

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push https://Cosmic-voyager-as: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@github.com/Cosmic-voyager-as/mnist-digit-recognition.git main
# Out:
# remote: Permission to Cosmic-voyager-as/mnist-digit-recognition.git denied to Cosmic-voyager-as.
# fatal: unable to access 'https://github.com/Cosmic-voyager-as/mnist-digit-recognition.git/': The requested URL returned error: 403

# %%
# %cd /content/mnist-digit-recognition
# !git remote remove origin
# Out:
# /content/mnist-digit-recognition

# %%
# !git remote add origin https://github.com/cosmic-voyager-as/mnist-digit-recognition.git

# %%
# !git config --global --unset credential.helper

# %%
# !git config --global credential.helper store

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
